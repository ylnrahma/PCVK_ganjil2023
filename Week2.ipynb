# %% [markdown]
# <a href="https://colab.research.google.com/github/ylnrahma/PCVK_ganjil2023/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Laporan Praktikum Pertemuan 2 - Pengolahan Citra dan Visi Komputer**
#
# Nama: Yuliyana Rahmawati
#
# NIM: 2141720241

# %% [markdown]
# **Langkah Praktikum**

# %% [markdown]
# 1.   Import Folder yang ada di Drive

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 2.   Membuka file Google Drive yang sudah ada. Contohnya pada kode program di bawah file image dengan nama kitten01.jpg akan dibuka untuk diproses lebih lanjut.

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/images/kitten01.jpg')
plt.imshow(img)#perhatikan hasilnya adalah citra dgn channel warna BGR

# %% [markdown]
# 3.   OpenCV membaca image dan menyimpan dalam channel warna BGR (Blue Green Red)Tampilkan nilai pixel dan image

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) #konversi BGR -> RGB
plt.imshow(img3)

# %% [markdown]
# 4.   Menampilkan citra Grayscale, melakukan resizing, melakukan Flipping, Menyimpan citra hasil

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %% [markdown]
# *   Cari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘gray'

# %%
#melakukan colormap 'gray'
plt.imshow(img_gray, cmap='gray')

# %% [markdown]
# *   Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘magma’

# %%
#colormap warna 'magma'
plt.imshow(img_gray, cmap='magma')

# %% [markdown]
# *   Citra RGB di resize dalam ukuran panjang 512 dan lebar 1024

# %%
#resize ukuran (panjang 512 dan lebar 1024)
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %% [markdown]
# *   Citra RGB ditampilkan dalam ukuran yang lebih besar dengan posisi gambar terbalik

# %%
# ukuran lebih besar dan terbalik
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

# tampilkan plat dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# 5.   Membuat bentuk Geometri 2D dari OpenCV. Diawali dengan pembuatan black image dengan tipe data int16.

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %% [markdown]
# *   Kemudian menambahkan bentuk persegi panjang sesuai koordinat pt1 dan pt2

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %% [markdown]
# *   Selanjutnya ditambah menambahkan bentuk persegi sesuai koordinat pt1 dan pt2 yang tertulis pada kode program.

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %% [markdown]
# *   Tahap selanjutnya ditambah menambahkan bentuk lingkaran sesuai radius yang tertulis pada kode program.

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %% [markdown]
# *   Tahap selanjutnya ditambah menambahkan bentuk lingkaran sesuai radius yang tertulis pada kode program

# %%
cv.circle(black_img,center=(400,400), radius=20,color=(255,0,0),thickness=100)
plt.imshow(black_img)

# %% [markdown]
# *   Kemudian dilakukan penambahan garis sesuai koordinat pt1 dan pt2 sebagai berikut.

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %% [markdown]
# *   Penambahan text dengan font yang telah tertulis dengan ukuran yang sudah
# ditentukan.

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %% [markdown]
# *   Pembuatan black image kembali dilakukan dengan tipe data int32

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %% [markdown]
# *   Berikut adalah kode program untuk inisialisasi NumPy array dengan tipe data int32

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %% [markdown]
# *   Array tersebut kemudian di reshape sebagai berikut

# %%
pts = vertices.reshape((-1,1,2))# nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %% [markdown]
# *   Penambahan polyline pada black image kedua yang telah dibuat.

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# 6.   Setelah semua kode selesai simpan “Week2.ipynb” pada GiHub Anda dengan memilih File kemudian “Save a copy in GitHub”.

# %% [markdown]
# #### **Pertanyaan**

# %% [markdown]
# 1.   Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
#
#     **Jawaban** : Tanpa matplotlib gambar yang ditampilkan memiliki aksi yang terbatas terhadap tampilan gambar sedangkan dengan matplotlib gambar yang ditampilkan memiliki aksi penuh terhadap tampilan gambar
#
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?
#
#     **Jawaban** : Jika menggunakan tipe data int16 maka memori yang digunakan lebih sedikit dan memiliki rentang nilai yang lebih terbatas
#
#     Jika menggunakan tipe data int32 maka memori yang digunakan lebih besar dan memiliki rentang nilai yang lebih besar, sehingga cocok untuk situasi di mana citra memiliki variasi intensitas yang besar.
#
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode berikut.
#
#     **Jawaban** : Fungsi google.colab.patches import cv2_imshow digunakan untuk menampilkan citra secara interaktif di lingkungan Google Colab. Ini memungkinkan Anda untuk melihat citra yang Anda proses atau visualisasikan dalam notebook Colab tanpa harus menyimpannya terlebih dahulu atau menampilkan di luar notebook.
#
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3.
#
#    ** Jawaban** : skimage import io untuk dengan mudah membaca, menampilkan, dan menyimpan citra dalam berbagai proyek pemrosesan citra.

# %% [markdown]
# ## **TUGAS**

# %% [markdown]
# Berdasarkan praktikum bagian 1 dan 2 kerjakan beberapa tugas berikut :

# %% [markdown]
# 1.   Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga
# berubah?
#
#     **Jawaban**: Tidak Berubah karena pengaturan figsize mengubah ukuran figur yang berisi gambar atau plot, bukan ukuran pixel dari gambar itu sendiri.

# %% [markdown]
# 2.   Tampilkan image dalam channel Red-Blue dan Green-Blue saja!

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# Membaca gambar dalam warna asli
img = cv.imread('/content/drive/MyDrive/PCVK/images/kitten01.jpg')

# Membuat citra baru hanya dengan saluran Red-Blue
red_blue = img.copy()
red_blue[:, :, 1] = 0  # Set saluran hijau menjadi 0 (hanya tinggalkan saluran merah dan biru)

# Menampilkan citra dalam saluran Red-Blue
plt.imshow(cv.cvtColor(red_blue, cv.COLOR_BGR2RGB))
plt.axis('off')
plt.title('Red-Blue Channel')
plt.show()

# %%
# GREEN-BLUE

import cv2 as cv
import matplotlib.pyplot as plt

# Membaca gambar dalam warna asli
img = cv.imread('/content/drive/MyDrive/PCVK/images/kitten01.jpg')

# Membuat citra baru hanya dengan saluran Green-Blue
green_blue = img.copy()
green_blue[:, :, 2] = 0  # Set saluran merah menjadi 0 (hanya tinggalkan saluran hijau dan biru)

# Menampilkan citra dalam saluran Green-Blue
plt.imshow(cv.cvtColor(green_blue, cv.COLOR_BGR2RGB))
plt.axis('off')
plt.title('Green-Blue Channel')
plt.show()

# %% [markdown]
# 3.   Tampilkan image baris ke 20-115, kolom 25-120!

# %%
import cv2
import matplotlib.pyplot as plt

# Membaca citra
image = cv2.imread('/content/drive/MyDrive/PCVK/images/kitten01.jpg')

# Memotong bagian tertentu dari citra
cropped_image = image[20:115, 25:120]

# Menampilkan citra hasil pemotongan
plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))
plt.title('Cropped Image')
plt.show()

# %% [markdown]
# 4.   Tampilkan image baris ke 5-30, semua kolom, channel Red saja!

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# Membaca citra
img = cv.imread('/content/drive/MyDrive/PCVK/images/kitten01.jpg')

# Membuat citra baru hanya dengan saluran Red
red = img.copy()
red [:, :, 1] = 0  # Set saluran hijau menjadi 0 (hanya tinggalkan saluran merah dan biru)

# Memotong bagian tertentu dari citra
cropped_image = image[5:30]

# Menampilkan citra dalam saluran Red
plt.imshow(cv.cvtColor(cropped_image, cv.COLOR_BGR2RGB))
plt.axis('off')
plt.title('Red Channel')
plt.show()

# %% [markdown]
# 5.   Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!

# %%
image1 = io.imread('/content/drive/MyDrive/PCVK/images/kitten01.jpg')

cv.rectangle(image1, pt1=(200,500), pt2=(300,300), color=(0,255,0), thickness=10)
cv.rectangle(image1, pt1=(300,200), pt2=(30,330), color=(255,0,0), thickness=10)
cv.rectangle(image1, pt1=(100,50), pt2=(30,200), color=(0,0,255), thickness=10)
cv.rectangle(image1,pt1=(70,400),pt2=(450,578),color=(0,0,0),thickness=12)
cv.rectangle(image1,pt1=(609,500),pt2=(110,300),color=(0,255,255),thickness=11)

plt.imshow(image1)

# %% [markdown]
# 6.   Tampilkan image dengan posisi terbalik!

# %%
image1 = io.imread('/content/drive/MyDrive/PCVK/images/kitten01.jpg')

cv.rectangle(image1, pt1=(200,500), pt2=(300,300), color=(0,255,0), thickness=10)
cv.rectangle(image1, pt1=(300,200), pt2=(30,330), color=(255,0,0), thickness=10)
cv.rectangle(image1, pt1=(100,50), pt2=(30,200), color=(0,0,255), thickness=10)
cv.rectangle(image1,pt1=(70,400),pt2=(450,578),color=(0,0,0),thickness=12)
cv.rectangle(image1,pt1=(609,500),pt2=(110,300),color=(0,255,255),thickness=11)

plt.imshow(image1)

image1_flip = cv2.flip(image1, 0)

plt.imshow(image1_flip)

# %% [markdown]
# *   Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :

# %% [markdown]
# 7.   Buat rectangle dan circle pada bagian wajah dari image foto anda saat
# beraktifitas (bukan pasfoto).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/images/ylrahma.jpg')
img = cv.cvtColor(img,cv.COLOR_BGR2RGB) #konversi BGR -> RGB

# membuat rectagle
cv.rectangle(img,pt1=(1000,1550),pt2=(440,2200),color=(0,255,0),thickness=8)

# membuat circle
cv.circle(img, center=(700,1880),radius=200,color=(0,0,255),thickness=10)

plt.imshow(img)

# %% [markdown]
# 8.   Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/images/kitten01.jpg')
img = cv.cvtColor(img,cv.COLOR_BGR2RGB) #konversi BGR -> RGB

# membuat rectagle
cv.rectangle(img,pt1=(180,700),pt2=(10,900),color=(255,255,0),thickness=10)

plt.imshow(img)

# %% [markdown]
# 9.   Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran font, dan warna font yang sesuai keinginan anda

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/images/kitten01.jpg')
img = cv.cvtColor(img,cv.COLOR_BGR2RGB) #konversi BGR -> RGB

# membuat rectagle
cv.rectangle(img,pt1=(180,700),pt2=(10,900),color=(255,255,0),thickness=10)
# membuat tulisan
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(img,text='Leo',org=(420,880), fontFace=font,fontScale=2,color=(255,0,255), thickness=10, lineType=cv.LINE_AA)
plt.imshow(img)

# %% [markdown]
# 10.   Tunjukkan code program anda pada bapak/ibu dosen
